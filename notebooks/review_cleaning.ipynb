# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

import pandas as pd

from src.preprocessing import clean_reviews
from src.preprocessing import save_cleaned_reviews

df = pd.read_csv("../data/appfolio_reviews_raw.csv")

df = clean_reviews(df)

df.head()
df.info()
df["review_length"].describe()

save_cleaned_reviews(
    df,
    "../data/cleaned_reviews.csv"
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              500 non-null    object
#  1   userName              500 non-null    object
#  2   userImage             500 non-null    object
#  3   content               500 non-null    object
#  4   score                 500 non-null    int64
#  5   thumbsUpCount         500 non-null    int64
#  6   reviewCreatedVersion  425 non-null    object
#  7   at                    500 non-null    object
#  8   replyContent          70 non-null     object
#  9   repliedAt             70 non-null     object
#  10  appVersion            425 non-null    object
#  11  review_length         500 non-null    int64
#  12  sentiment             500 non-null    object
# dtypes: int64(3), object(10)
# memory usage: 50.9+ KB
