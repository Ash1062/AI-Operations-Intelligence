# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

import pandas as pd

from src.intelligence import (
    generate_all_intelligence,
    save_intelligence
)

# %%
df = pd.read_csv(
    "../data/classified_operational_reviews.csv"
)

df.head()
# Out:
#                                reviewId          userName  \
# 0  d5b38a94-65f1-4708-9567-6cadaee3ee75  Eloise S Colbert
# 1  395dce08-418a-4572-b1ec-2185e11cde76        Tom Cullen
# 2  28bbaaa6-272b-4c5f-8e21-c9b299c5cadb             Brian
# 3  951b166e-1d05-4f9f-b525-13e2aed65180     Linda Binanti
# 4  d4fc20c5-abd5-42ef-8756-0b5fe4a3c098         Antonio R
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0                           didn't work right always      2              0
# 1  Never pay rent on a portal. If you've already ...      1              0
# ...

# %%
all_results = generate_all_intelligence(df)
# Out:
# Analyzing Other Operational Issue...
# Analyzing Payments...
# Analyzing UI / Usability...
# Analyzing Authentication...
# Analyzing Maintenance...
# Analyzing Stability...

# %%
save_intelligence(
    all_results,
    "../data/operations_intelligence.json"
)

print("Operations intelligence saved successfully.")
# Out:
# Operations intelligence saved successfully.
